# %%
# Importating the libraries
import numpy as np
import pandas as pd
df1 = pd.read_csv("D://Sem 3//Hemlata Maam//Bread Basket//BreadBasket_DMS.csv")

# %%
df1.shape
# Out:
# (21293, 4)

# %%
df1.head(10)
# Out:
#          Date      Time  Transaction           Item
# 0  2016-10-30  09:58:11            1          Bread
# 1  2016-10-30  10:05:34            2   Scandinavian
# 2  2016-10-30  10:05:34            2   Scandinavian
# 3  2016-10-30  10:07:57            3  Hot chocolate
# 4  2016-10-30  10:07:57            3            Jam
# 5  2016-10-30  10:07:57            3        Cookies
# 6  2016-10-30  10:08:41            4         Muffin
# 7  2016-10-30  10:13:03            5         Coffee
# 8  2016-10-30  10:13:03            5         Pastry
# 9  2016-10-30  10:13:03            5          Bread

# %%
# checking the null values in the data set & print them in an ascending order
df1.isnull().sum().sort_values(ascending=False)
# Out:
# Item           0
# Transaction    0
# Time           0
# Date           0
# dtype: int64

# %%
# Sales of items 
count = df1['Item'].value_counts() 
print(count)
# Out:
# Coffee                           5471
# Bread                            3325
# Tea                              1435
# Cake                             1025
# Pastry                            856
# NONE                              786
# Sandwich                          771
# Medialuna                         616
# Hot chocolate                     590
# Cookies                           540
# Brownie                           379
# Farm House                        374
# Muffin                            370
# Juice                             369
# Alfajores                         369
# Soup                              342
# Scone                             327
# Toast                             318
# Scandinavian                      277
# Truffles                          193
# Coke                              185
# Spanish Brunch                    172
# Fudge                             159
# Baguette                          152
# Jam                               149
# ...

# %%
#Total number of unique items present
len(df1['Item'].unique().tolist())
# Out:
# 95

# %%
#delete a particular item in a column/ printed those rows that do not have a NONE value
df1 = df1[df1.Item!='NONE']
df1
# Out:
#              Date      Time  Transaction                  Item
# 0      2016-10-30  09:58:11            1                 Bread
# 1      2016-10-30  10:05:34            2          Scandinavian
# 2      2016-10-30  10:05:34            2          Scandinavian
# 3      2016-10-30  10:07:57            3         Hot chocolate
# 4      2016-10-30  10:07:57            3                   Jam
# 5      2016-10-30  10:07:57            3               Cookies
# 6      2016-10-30  10:08:41            4                Muffin
# 7      2016-10-30  10:13:03            5                Coffee
# 8      2016-10-30  10:13:03            5                Pastry
# 9      2016-10-30  10:13:03            5                 Bread
# 10     2016-10-30  10:16:55            6             Medialuna
# 11     2016-10-30  10:16:55            6                Pastry
# 12     2016-10-30  10:16:55            6                Muffin
# 13     2016-10-30  10:19:12            7             Medialuna
# ...

# %%
#Total number of unique items present
len(df1['Item'].unique().tolist())
# Out:
# 94

# %%
#Import the following libraries// apriori is used for association rules & structured relationships
import seaborn as sns
import matplotlib.pyplot as plt
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
import mlxtend as ml

# %%
bb = df1.groupby(['Transaction','Item']).size().reset_index(name='count')
basket = (bb.groupby(['Transaction', 'Item'])['count']
          .sum().unstack().reset_index().fillna(0)
          .set_index('Transaction'))

#The encoding function
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1
basket_sets = basket.applymap(encode_units)

# %%
# FInal Output of Bread Basket

frequent_itemsets = apriori(basket_sets, min_support=0.01, use_colnames=True)
rules = association_rules(frequent_itemsets, metric="lift")
rules.sort_values('confidence', ascending = False, inplace = True)
rules.head(10)
# Out:
#          antecedents consequents  antecedent support  consequent support  \
# 41           (Toast)    (Coffee)            0.033597            0.478394
# 39  (Spanish Brunch)    (Coffee)            0.018172            0.478394
# 27       (Medialuna)    (Coffee)            0.061807            0.478394
# 31          (Pastry)    (Coffee)            0.086107            0.478394
# 2        (Alfajores)    (Coffee)            0.036344            0.478394
# 25           (Juice)    (Coffee)            0.038563            0.478394
# 33        (Sandwich)    (Coffee)            0.071844            0.478394
# 15            (Cake)    (Coffee)            0.103856            0.478394
# 35           (Scone)    (Coffee)            0.034548            0.478394
# 21         (Cookies)    (Coffee)            0.054411            0.478394
#
#      support  confidence      lift  leverage  conviction
# 41  0.023666    0.704403  1.472431  0.007593    1.764582
# ...

# %%
# Support is the percentage of transactions containing a particular combination of items 
# relative to the total number of transactions in the database.

# Confidence measures how much the consequent (item) is dependent on the antecedent (item)

# Lift is said to measure the difference — measured in ratio — between the confidence of a rule and the expected confidence.
